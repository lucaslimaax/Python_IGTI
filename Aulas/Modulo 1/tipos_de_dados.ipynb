# %%
TIPOS DE DADOS

# %%
#ATRIBUIÇÃO DE VALORES

cateto_a=4

endereco=id(cateto_a)
print(endereco)
# Out:
# 10914592

# %%
hexa_endereco=hex(endereco)
hexa_endereco_2=hex(endereco)

print(endereco)
print(endereco)
# Out:
# 10914592
# 10914592
